# %%
from bardapi import Bard
import os
import pandas as pd
# token='bQjbGtR9xrFsy8A1T01dJER1REGZxXzGxJHAzWKbPR7OjMSKbMr07o4mZgrp1m6KGcS2-g.'

# Bard(token=token).get_answer("describe brazil in one word without explaination")['content']

# %%
df=pd.read_csv(r'C:\Users\Kirte\OneDrive\Documents\enron_mails_subsample.csv')
df
# Out:
#                                          RawMailContent
# 0     Message-ID: <21713028.1075855434284.JavaMail.e...
# 1     Message-ID: <30445252.1075855073917.JavaMail.e...
# 2     Message-ID: <12158479.1075847131465.JavaMail.e...
# 3     Message-ID: <13684295.1075845928316.JavaMail.e...
# 4     Message-ID: <2352172.1075842967105.JavaMail.ev...
# ...                                                 ...
# 4995  Message-ID: <10566838.1075846391124.JavaMail.e...
# 4996  Message-ID: <32232039.1075847075437.JavaMail.e...
# 4997  Message-ID: <9769889.1075858707282.JavaMail.ev...
# 4998  Message-ID: <31276235.1075846020705.JavaMail.e...
# 4999  Message-ID: <28545397.1075846014448.JavaMail.e...
#
# [5000 rows x 1 columns]

# %%
df['Message-ID']=df['RawMailContent'].str.extract('Message-ID'+r':\s(.*)\n')
df['Subject']=df['RawMailContent'].str.extract('Subject'+r':\s(.*)\n')
df['Body']=df['RawMailContent'].str.extract('X-FileName'+r':\s.*\n([\s\S]*)$')
df.drop('RawMailContent',axis=1,inplace=True)
df['Body']=df['Body'].replace({'\n':' ','\t':' '},regex=True)

df['Body']=df['Body'].replace({'"':'',"'":""},regex=True)
df['Subject']=df['Subject'].replace({'"':'',"'":""},regex=True)

df.loc[df['Body'].str.contains('-----Original Message-----'),'Body']
df.loc[df['Body'].str.contains('-----Original Message-----'),'Body']
# Out:
# 0         Forwarded for tracking purposes.  -----Origi...
# 2        Tana,  Hope you are well.  I wondered whether...
# 12       Debra Perlingiere Enron North America Corp. L...
# 13       Bob -  I believe what we sent them was a form...
# 17       This one is easy, Texas Gas k#T018123 was rec...
#                               ...
# 4967     I thought this one was funny enough to forwar...
# 4972     it was really good.  howd you cut up those da...
# 4979     Alan, heres the open season announcement I se...
# 4986     I was reading through your and others recomme...
# 4997     Attached below is a 9 page summary of what Ch...
# Name: Body, Length: 737, dtype: object

# %%
df.loc[df['Body'].str.contains('-----Original Message-----'),'Body']=df.loc[df['Body'].str.contains('-----Original Message-----'),'Body'].str.extract(r'([\s\S]*?)'+r'-----Original Message-----',expand=False)
# 
df
# Out:
#                                          Message-ID  \
# 0     <21713028.1075855434284.JavaMail.evans@thyme>
# 1     <30445252.1075855073917.JavaMail.evans@thyme>
# 2     <12158479.1075847131465.JavaMail.evans@thyme>
# 3     <13684295.1075845928316.JavaMail.evans@thyme>
# 4      <2352172.1075842967105.JavaMail.evans@thyme>
# ...                                             ...
# 4995  <10566838.1075846391124.JavaMail.evans@thyme>
# 4996  <32232039.1075847075437.JavaMail.evans@thyme>
# 4997   <9769889.1075858707282.JavaMail.evans@thyme>
# 4998  <31276235.1075846020705.JavaMail.evans@thyme>
# 4999  <28545397.1075846014448.JavaMail.evans@thyme>
#
#                                                 Subject  \
# 0     FW: Notice of Termination - Power Purchase and...
# 1
# 2          RE: FW: Deutsche Bank ISDA Master Agreements
# 3                     Re: FW: VEPCO/City of Rocky Mount
# 4
# ...                                                 ...
# 4995                                Letter to John Pope
# 4996                         Re: New CAs & Revised List
# 4997            FW: Summary of Sections to be marked up
# 4998  World Hunger- Section 9.6 Additional tests - t...
# 4999  Re: Dinner on Wednesday, May 2, 2001, San Anto...
#
#                                                    Body
# 0                    Forwarded for tracking purposes.
# 1       Return Receipt   Your  document:   was recei...
# 2      Tana,  Hope you are well.  I wondered whether...
# 3      Im travelling on Monday, so please ask my ass...
# 4      If theres other stuff you need, or if youd li...
# ...                                                 ...
# 4995   Attached is a new draft of the letter to John...
# 4996   One comment - the Platts agreement has been c...
# 4997   Attached below is a 9 page summary of what Ch...
# 4998   9.6  Additional Factory Testing .  In the eve...
# 4999   I have a closing scheduled for Wednesday, so ...
#
# [5000 rows x 3 columns]

# %%
df['Body']=df['Body'].str.strip()
df['Subject']=df['Subject'].str.strip()
df['Body']=df['Subject']+df['Body']
df.drop('Subject', axis=1, inplace=True)
df
# Out:
#                                          Message-ID  \
# 0     <21713028.1075855434284.JavaMail.evans@thyme>
# 1     <30445252.1075855073917.JavaMail.evans@thyme>
# 2     <12158479.1075847131465.JavaMail.evans@thyme>
# 3     <13684295.1075845928316.JavaMail.evans@thyme>
# 4      <2352172.1075842967105.JavaMail.evans@thyme>
# ...                                             ...
# 4995  <10566838.1075846391124.JavaMail.evans@thyme>
# 4996  <32232039.1075847075437.JavaMail.evans@thyme>
# 4997   <9769889.1075858707282.JavaMail.evans@thyme>
# 4998  <31276235.1075846020705.JavaMail.evans@thyme>
# 4999  <28545397.1075846014448.JavaMail.evans@thyme>
#
#                                                    Body
# 0     FW: Notice of Termination - Power Purchase and...
# 1     Return Receipt   Your  document:   was receive...
# 2     RE: FW: Deutsche Bank ISDA Master AgreementsTa...
# 3     Re: FW: VEPCO/City of Rocky MountIm travelling...
# 4     If theres other stuff you need, or if youd lik...
# ...                                                 ...
# 4995  Letter to John PopeAttached is a new draft of ...
# 4996  Re: New CAs & Revised ListOne comment - the Pl...
# 4997  FW: Summary of Sections to be marked upAttache...
# 4998  World Hunger- Section 9.6 Additional tests - t...
# 4999  Re: Dinner on Wednesday, May 2, 2001, San Anto...
#
# [5000 rows x 2 columns]

# %%
df1=pd.read_csv('enron_removed.csv')
df1=df1['message_id']
df1=list(df1)
df=df[~df['Message-ID'].isin(df1)]
df=df.iloc[550:600]

# %%
df
# Out:
#                                         Message-ID  \
# 551  <22550582.1075847205268.JavaMail.evans@thyme>
# 552  <11253692.1075845623809.JavaMail.evans@thyme>
# 553  <29269080.1075842922976.JavaMail.evans@thyme>
# 554  <21809204.1075855248345.JavaMail.evans@thyme>
# 555    <315068.1075846723718.JavaMail.evans@thyme>
# 556  <13855865.1075862417511.JavaMail.evans@thyme>
# 557  <23042732.1075844565486.JavaMail.evans@thyme>
# 558  <27610119.1075855854297.JavaMail.evans@thyme>
# 559  <22948909.1075859974452.JavaMail.evans@thyme>
# 560  <30553188.1075855658549.JavaMail.evans@thyme>
# 561  <28218042.1075862339883.JavaMail.evans@thyme>
# 562  <11626093.1075841379251.JavaMail.evans@thyme>
# 563   <7588030.1075856777858.JavaMail.evans@thyme>
# 564  <31566707.1075846089605.JavaMail.evans@thyme>
# 565   <7659768.1075854326242.JavaMail.evans@thyme>
# 566   <4645160.1075851879031.JavaMail.evans@thyme>
# 567  <29742395.1075860579046.JavaMail.evans@thyme>
# 568  <13349622.1075847358588.JavaMail.evans@thyme>
# 569  <14829640.1075858648179.JavaMail.evans@thyme>
# 570  <31426254.1075845731652.JavaMail.evans@thyme>
# 571   <9229291.1075860867806.JavaMail.evans@thyme>
# 572  <16378641.1075845307372.JavaMail.evans@thyme>
# 573  <12145587.1075842003027.JavaMail.evans@thyme>
# 574   <8523893.1075841298909.JavaMail.evans@thyme>
# 575  <19995198.1075840431527.JavaMail.evans@thyme>
# 576  <17804716.1075857809374.JavaMail.evans@thyme>
# 577   <1197166.1075843878226.JavaMail.evans@thyme>
# 578   <1626096.1075857319624.JavaMail.evans@thyme>
# 579   <4864105.1075851593386.JavaMail.evans@thyme>
# 580  <19283956.1075844382919.JavaMail.evans@thyme>
# 581  <19476269.1075841608717.JavaMail.evans@thyme>
# 582  <20014618.1075859906291.JavaMail.evans@thyme>
# 583  <23631382.1075845581750.JavaMail.evans@thyme>
# 584  <12775069.1075857173843.JavaMail.evans@thyme>
# 585   <7999824.1075863632712.JavaMail.evans@thyme>
# 586  <18752707.1075860476922.JavaMail.evans@thyme>
# 587  <19505988.1075845382207.JavaMail.evans@thyme>
# 588    <988408.1075862019729.JavaMail.evans@thyme>
# 589  <24583876.1075851836439.JavaMail.evans@thyme>
# 590    <275054.1075857425534.JavaMail.evans@thyme>
# 591  <17097355.1075839989513.JavaMail.evans@thyme>
# 592   <9540374.1075847724049.JavaMail.evans@thyme>
# 593  <15688585.1075861137782.JavaMail.evans@thyme>
# 594  <13983827.1075853085854.JavaMail.evans@thyme>
# 595  <30123628.1075860738333.JavaMail.evans@thyme>
# 596  <18923155.1075840649294.JavaMail.evans@thyme>
# 597   <7627867.1075841499151.JavaMail.evans@thyme>
# 598  <31548151.1075856636276.JavaMail.evans@thyme>
# 599  <28245885.1075840681014.JavaMail.evans@thyme>
# 600  <16352292.1075847977290.JavaMail.evans@thyme>
#
#                                                   Body
# 551  Springs SWAP ConfirmationsAt Brents request, I...
# 552  Re: LM6000 Contract Payment Allocations-------...
# 553  Executive Committee List - UpdateUpdates Jenni...
# 554  NRG loiHeres a first draft of the NRG loi.    ...
# 555  PNM filingFYI:  This morning, Lorraine and I c...
# 556  La Plata to Bloomfield Drag Reducing Agent App...
# 557  Re: Cinergy Marketing ISDA UpdateIts on my cal...
# 558  Speaking Engagement for Operations Controller ...
# 559  Re: Speaking opportunityEnron Broadband Servic...
# 560  eThink About It: 5/7/01Thursday, May 10 at 10 ...
# 561  Answer on Mondays bank meeting.Mondays bank me...
# 562  RE:Is that frequent Distressed Bowel Disorder,...
# 563  Template for pricing the right of first refusa...
# 564  ENA / Coral Turbine Transactionplease print --...
# 565  Re: Deal 502952Deal 606396 is already in Sitar...
# 566  Nitrogen in FuelLarry:  Ruth indicated you are...
# 567  FW:fyi ---------------------- Forwarded by Ric...
# 568  RE: Financial trade agreements databaseTana - ...
# 569  RE: Renewables call tomorrow - reschedule?That...
# 570  Re: Yes, they are deducting for parkingLet me ...
# 571  Fwd: Fw: Fw: Fw: Fw: Some gems from teachers>F...
# 572  Investinme Course OfferingPresentations That W...
# 573  NETCO Implemention TemplateFrom Kevin Presto: ...
# 574  Schedule Crawler: HourAhead FailureStart Date:...
# 575  Save 30% - 65% on Accessories[IMAGE]          ...
# 576  michcon flowsLiz,  Heres the file.  Thanks for...
# 577  Wrong NumberGreetings Diane:  Could you check ...
# 578  RecruitingAre you guys looking to hire any ana...
# 579  Enron MentionsThe Player; Blockbuster plays ha...
# 580  Re: weather confirmI thought this was what we ...
# 581       RE: Product ListStill unknown...min. 60 days
# 582  Photos---------------------- Forwarded by Mark...
# 583  Re: VEPCONancy,  I dont have details on the me...
# 584  Re:Hey Mike, Thanks for the pics.  Where were ...
# 585  Mid-Year 2000 Performance FeedbackNOTE:  YOU W...
# 586  Confidential Attorney Client Privilege - Attor...
# 587  FW: A Little ProofTo: Subject: Date: Thu, 17 M...
# 588  FW: STENO NUMBERSHere is a list for the schedu...
# 589  NEPOOL Historical Data ModelLocated at:  M:\El...
# 590  Re: Test deals for your reviewDawne,  I looked...
# 591  Start Date: 12/14/01; HourAhead hour: 2;Start ...
# 592  Technology Daily AM: Music Industry, Aimster S...
# 593  RE: F.P.U. NEW SMYRNA DELIVERY POINT QUESTIONT...
# 594  Spencer Abraham, US Energy Secretary on US Ene...
# 595  STORAGE NOTESStorage Notes January 4, 2002    ...
# 596  Length at PVSold this energy for 7-22 to TEP. ...
# 597  eBayhttp://cgi.ebay.com/aw-cgi/eBayISAPI.dll?V...
# 598  RE: Enron Case Study UpdateGood afternoon John...
# 599  RE: FW: hi!oh, how generous of you.  Youre too...
# 600  State Controller Kathleen Connell Press Confer...

# %%
token='bgjbGq6GRN544o81rtCSJk5vXUGihQ1qHLs-AD015WbDz9IlofyK1R2_y4nlZsydOYnZ8Q.'

# %%
os.environ['_BARD_API_KEY']=token
def bard_output(input_text):
    input_text='Please categorise the following mail body into one of the 7 categories without any explaination, mention only the category as output 1) Company Business, Strategy, etc. 2) Purely Personal 3) Personal but in professional context 4) Logistic Arrangements(meeting scheduling, technical support, etc) 5) Employment arrangements(job seeking, hiring, recommendations, etc) 6) Document editing/checking(collaboration) 7) Payroll, finance, accounting etc.' + input_text
    return Bard().get_answer(input_text)['content']
df['result']=df['Body'].apply(bard_output)
df
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[21], line 5
#       3     input_text='Please categorise the following mail body into one of the 7 categories without any explaination, mention only the category as output 1) Company Business, Strategy, etc. 2) Purely Personal 3) Personal but in professional context 4) Logistic Arrangements(meeting scheduling, technical support, etc) 5) Employment arrangements(job seeking, hiring, recommendations, etc) 6) Document editing/checking(collaboration) 7) Payroll, finance, accounting etc.' + input_text
#       4     return Bard().get_answer(input_text)['content']
# ----> 5 df['result']=df['Body'].apply(bard_output)
#       6 df
#
# File ~\miniconda3\envs\garudmki\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\miniconda3\envs\garudmki\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~\miniconda3\envs\garudmki\lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\miniconda3\envs\garudmki\lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[21], line 4, in bard_output(input_text)
#       2 def bard_output(input_text):
#       3     input_text='Please categorise the following mail body into one of the 7 categories without any explaination, mention only the category as output 1) Company Business, Strategy, etc. 2) Purely Personal 3) Personal but in professional context 4) Logistic Arrangements(meeting scheduling, technical support, etc) 5) Employment arrangements(job seeking, hiring, recommendations, etc) 6) Document editing/checking(collaboration) 7) Payroll, finance, accounting etc.' + input_text
# ----> 4     return Bard().get_answer(input_text)['content']
#
# File ~\miniconda3\envs\garudmki\lib\site-packages\bardapi\core.py:70, in Bard.__init__(self, token, timeout, proxies, session, conversation_id, google_translator_api_key, language, run_code, token_from_browser)
#      68 self.choice_id = ""
#      69 self.session = self._get_session(session)
# ---> 70 self.SNlM0e = self._get_snim0e()
#      71 self.language = language or os.getenv("_BARD_API_LANG")
#      72 self.run_code = run_code
#
# File ~\miniconda3\envs\garudmki\lib\site-packages\bardapi\core.py:138, in Bard._get_snim0e(self)
#     134 resp = self.session.get(
#     135     "https://bard.google.com/", timeout=self.timeout, proxies=self.proxies
#     136 )
#     137 if resp.status_code != 200:
# --> 138     raise Exception(
#     139         f"Response status code is not 200. Response Status is {resp.status_code}"
#     140     )
#     141 snim0e = re.search(r"SNlM0e\":\"(.*?)\"", resp.text)
#     142 if not snim0e:
#
# Exception: Response status code is not 200. Response Status is 429

# %%
df['result'].iloc[19]
